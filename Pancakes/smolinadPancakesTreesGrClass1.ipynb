# %% [markdown]
# # Lab 8 - Pancakes with a problem!
# Sebastian Leonardo Molina Diaz - smolinad@unal.edu.co

# %% [markdown]
# ![pancakespilesPythonlists.png](http://ungrid.unal.edu.co/gjhernandezp/algorithms/pancakes/pancakespilesPythonlistsonespatula.png)

# %%
import pydot
from collections import defaultdict 
from IPython.display import Image, display

# %%
def lstr(p):
        return ''.join([str(elem)  for elem in p])

# %%
def ModifiedBFS(s): 

        # Create dictionaries graph, visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            node = pydot.Node(lstr(s))
            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If an adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                    node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
              
        # Display the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [1,3,2]
ModifiedBFS(p)

# %%
def ModifiedBFSPreSols(s): 

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                     node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [1,3,2]
ModifiedBFSPreSols(p)

# %%
def ModifiedBFSPreSolsLevel(s,L):  

        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append([s,0]) 
        visited[lstr(s)] = True
  
        while queue: 
  
            # Dequeue a vertex from queue 
            e = queue.pop(0)
            s = e[0]
            l = e[1] 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)) and (l < L):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                     node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append([d,l+1]) 
                  visited[lstr(d)] = True 
              
        # Dsplay the pydot graph G
        im = Image(G.create_png())
        display(im)

# %%
p = [5,2,3,4,1]
ModifiedBFSPreSolsLevel(p,3)

# %%
ModifiedBFSPreSolsLevel(p,5)

# %%
p = [2,3,4,1]
ModifiedBFSPreSolsLevel(p,5)

# %% [markdown]
# #1.
# Modify the [PancakesTrees.ipynb](https://github.com/gjhernandezp/algorithms/blob/master/PancakesTrees.ipynb) code in your own to plot the Pancake Network and calculate $P(n)$ for small $n$‘s.

# %%
import random
from IPython.display import display, Latex, Markdown

# %% [markdown]
# For $n$-sized Pancake Towers in random order, with $3 \leq n < 10$. The results of calculating $P(n)$ for every $n$-sized tower permutation are shown in the Exercise 2.

# %%
def create_tower(n):
    l = list(range(1, n+1))
    random.shuffle(l)
    return l
    
for k in range(3, 10):
    arg = create_tower(k)
    display(Markdown('<br> $n = $' + ' ' + str(k)))
    ModifiedBFSPreSolsLevel(arg, 5)
# Out:
# <br> $n = $ 3
# <br> $n = $ 4
# <br> $n = $ 5
# <br> $n = $ 6
# <br> $n = $ 7
# <br> $n = $ 8
# <br> $n = $ 9

# %% [markdown]
# #2.
# Modify the [PancakesTrees.ipynb](https://github.com/gjhernandezp/algorithms/blob/master/PancakesTrees.ipynb) code leaving only the necessary code and data structures required to calculate $P(n)$ and run the code for at least one night (8 hours) starting with $n=5$. What is the largest $P(n)$ calculated? (Save the results in Drive to avoid losing them)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import itertools
import pandas as pd
import numpy as np

# %%
def find_path(graph, start, end, path=[]):
    path = path + [start]
    if start == end:
        return path
    for node in graph[start]:
        if node not in path:
            newpath = find_path(graph, node, end, path)
            if newpath:
                return newpath

# %%
def pancakes(s):
        start = lstr(s)
        end = lstr(sorted(s))
        # Create dictionaries graph,visited and pydot graph G
        graph = defaultdict()
        visited = defaultdict()
        
        # Create a queue for BFS 
        queue = [] 
  
        # Mark the source node as visited and enqueue it 
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
            # Dequeue a vertex from queue 
            s = queue.pop(0) 
            graph[lstr(s)]=[]
            
            # Get all adjacent vertices of the 
            # dequeued vertex s. If a adjacent 
            # has not been visited, then mark it 
            # visited and enqueue it 
            if(s != sorted(s)):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 

        path = find_path(graph, start, end)
        return len(path) - 1

# %%
d = {'tower': [], 'min_flips': []}
n = 8

# %%
import time

max_time = int(60*60*8)
start_time = time.time()  
while (time.time() - start_time) < max_time:
    d['tower'].append(n)
    d['min_flips'].append("NaN")
    iterable = itertools.permutations(list(range(1, n+1)))
    permutations = list(iterable)
    for p in permutations:
        d['tower'].append(lstr(p))
        d['min_flips'].append(pancakes(p))
    n += 1

# %%
d['min_flips'] = np.array(d['min_flips'])
d['tower'] = np.array(d['tower'])
dataframe = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in d.items() ]))
dataframe.to_excel("p_n_2.xlsx", index=False)
# !cp p_n_2.xlsx "drive/My Drive/PancakesTrees"

# %%
dataframe.to_csv("p_n_2.csv", index=False)
# !cp p_n_2.csv "drive/My Drive/PancakesTrees"

# %%
d1 = pd.read_csv("/content/p_n.csv")
d2 = pd.read_csv("/content/p_n_2.csv")
d1.head()
# Out:
#    tower  min_flips
# 0      3        NaN
# 1    123        0.0
# 2    132        3.0
# 3    213        1.0
# 4    231        2.0

# %%
pancakes_flips = pd.concat([d1, d2])
pancakes_flips.drop_duplicates()
# Out:
#           tower  min_flips
# 0             3        NaN
# 1           123        0.0
# 2           132        3.0
# 3           213        1.0
# 4           231        2.0
# ...         ...        ...
# 17936  45832176        5.0
# 17937  45832617        6.0
# 17938  45832671        6.0
# 17939  45832716        6.0
# 17940  45832761        NaN
#
# [23857 rows x 2 columns]

# %% [markdown]
# As it can be seen from the last dataset, the largest $P(n)$ calculated after 8 hours is $n=8$, starting by $n=3$ until the permutation $45832716$. By error, the algorithm was started with $n=3$, however there is no big difference if it was started at $n=5$ after 8 hours.

# %% [markdown]
# #3.
# Modify the [PancakesTrees.ipynb](https://github.com/gjhernandezp/algorithms/blob/master/PancakesTrees.ipynb) code to plot the pancakes trees using two spatulas.

# %% [markdown]
# ## References
#
# - Breadth First Search or BFS for a Graph https://www.geeksforgeeks.org/breadth-first-search-or-bfs-for-a-graph/
#
# - Graph visualization using Python https://www.youtube.com/watch?v=SpDI6-FvtJY
#
# - nikhilkumarsingh
# /
# PyDot-Examples https://github.com/nikhilkumarsingh/PyDot-Examples/blob/master/Directory_Structure_Plotter.ipynb
#
# - pydot https://pypi.org/project/pydot/
#
# - Graphviz https://www.graphviz.org/
#
# - NetworkX https://networkx.github.io/
